# %%
## Set up the sys.path in order to be able to import our modules
import os
import sys
module_path = os.path.abspath(os.path.join('../python'))
if module_path not in sys.path:
    sys.path.append(module_path)
module_path = os.path.abspath(os.path.join('/data/alpha-transform'))
if module_path not in sys.path:
    sys.path.append(module_path)
#os.environ["CUDA_VISIBLE_DEVICES"]="1" #"0" for the 1st GPU or "1" to use the 2nd

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
SNR = [20,40,60,80,100]
el1=[0.12996797693425555, 0.07521722408526657, 0.05312232690521345, 0.04251763524947888, 0.03590849353048334] #gamma=0.002
el2=[0.13178018862266572, 0.0748990244380758, 0.05473324415867597, 0.042886459066129035, 0.037057858839072186] #gamma=0
el3=[0.1335670622438172, 0.07616597624023203, 0.05422738307132122, 0.04316628164661919, 0.03676002202569843] #gamma=0.01
el4=[0.1319681769224127, 0.07443749206284282, 0.053658309828252065, 0.04187332343928441, 0.03585514828703083] #gamma=0.001
el5=[0.13196129407457408, 0.07442093232976567, 0.053953724483578096, 0.042910023077831594, 0.0366126148204233] #gamma=0.0001 restart
el6=[0.13419318721020376, 0.07589833495638175, 0.054522158146289294, 0.04339945548356849, 0.037175221140754826] #gamma=0.001 restart
el7=[0.1322034873573254, 0.07550514111432349, 0.05442957986693242, 0.04444427398608336, 0.03819719403846264] #gamma=0.01 restart
el8=[0.13944247908941032, 0.082990275741912, 0.062203100451955685, 0.05014595600198679, 0.0439977060162449] #gamma=0.1 restart
el9=[0.1307681843836712, 0.07471274240605105, 0.05289594844127478, 0.04290581714611534, 0.03648747188328319] #gamma=0.004

# %%
gamma_list=np.array([el2,el4,el1,el9,el3])
gamma_restart_list=np.array([el2,el5,el6,el7])

# %%
plt.plot(SNR,el1,SNR,el2,SNR,el3,SNR,el4,SNR,el5,SNR,el6,SNR,el7,SNR,el9)
plt.legend(('gamma=0.002','gamma=0','gamma=0.01','gamma=0.001','gamma=0.0001r','gamma=0.001r','gamma=0.01r','gamma=0.004'))

# %%
#SHEARLETS
# gamma=1 : [0.12825316191484493, 0.07476244841015806, 0.053427960986229824, 0.04242910274444691, 0.036363412550621796]
#gamma=10 : [0.12927683232110712, 0.07426803907163289, 0.05301229779918684, 0.0417607048331968, 0.036159538698976236]

'''ShapeNet2D_claire_sc4_layer4x5x6x7_relu_growthRate12_with_shape_gamma10_shearlet.hdf5  SNR= 100 MEAN_ERR= 0.03467085343215709 MEDIAN_ERR= 0.03467085343215709
ShapeNet2D_claire_sc4_layer4x5x6x7_relu_growthRate12_with_shape_gamma10_shearlet.hdf5  SNR= 40 MEAN_ERR= 0.05771524840876463 MEDIAN_ERR= 0.05771524840876463
ShapeNet2D_claire_sc4_layer4x5x6x7_relu_growthRate12_with_shape_gamma10_shearlet.hdf5  SNR= 80 MEAN_ERR= 0.038394077795658135 MEDIAN_ERR= 0.038394077795658135
ShapeNet2D_claire_sc4_layer4x5x6x7_relu_growthRate12_with_shape_gamma10_shearlet.hdf5  SNR= 60 MEAN_ERR= 0.044928157870593316 MEDIAN_ERR= 0.044928157870593316
ShapeNet2D_claire_sc4_layer4x5x6x7_relu_growthRate12_with_shape_gamma10_shearlet.hdf5  SNR= 20 MEAN_ERR= 0.09723227450885938 MEDIAN_ERR= 0.09723227450885938

ShapeNet2D_claire_sc4_layer4x5x6x7_relu_growthRate12_with_shape_gamma1_shearlet.hdf5  SNR= 20 MEAN_ERR= 0.09366036723347601 MEDIAN_ERR= 0.09366036723347601
ShapeNet2D_claire_sc4_layer4x5x6x7_relu_growthRate12_with_shape_gamma1_shearlet.hdf5  SNR= 40 MEAN_ERR= 0.05634240667458698 MEDIAN_ERR= 0.05634240667458698
ShapeNet2D_claire_sc4_layer4x5x6x7_relu_growthRate12_with_shape_gamma1_shearlet.hdf5  SNR= 80 MEAN_ERR= 0.03746404041815238 MEDIAN_ERR= 0.03746404041815238
ShapeNet2D_claire_sc4_layer4x5x6x7_relu_growthRate12_with_shape_gamma1_shearlet.hdf5  SNR= 100 MEAN_ERR= 0.03372647545397815 MEDIAN_ERR= 0.03372647545397815
ShapeNet2D_claire_sc4_layer4x5x6x7_relu_growthRate12_with_shape_gamma1_shearlet.hdf5  SNR= 60 MEAN_ERR= 0.04419143684631882 MEDIAN_ERR= 0.04419143684631882'''
# Out:
# 'ShapeNet2D_claire_sc4_layer4x5x6x7_relu_growthRate12_with_shape_gamma10_shearlet.hdf5  SNR= 100 MEAN_ERR= 0.03467085343215709 MEDIAN_ERR= 0.03467085343215709\nShapeNet2D_claire_sc4_layer4x5x6x7_relu_growthRate12_with_shape_gamma10_shearlet.hdf5  SNR= 40 MEAN_ERR= 0.05771524840876463 MEDIAN_ERR= 0.05771524840876463\nShapeNet2D_claire_sc4_layer4x5x6x7_relu_growthRate12_with_shape_gamma10_shearlet.hdf5  SNR= 80 MEAN_ERR= 0.038394077795658135 MEDIAN_ERR= 0.038394077795658135\nShapeNet2D_claire_sc4_layer4x5x6x7_relu_growthRate12_with_shape_gamma10_shearlet.hdf5  SNR= 60 MEAN_ERR= 0.044928157870593316 MEDIAN_ERR= 0.044928157870593316\nShapeNet2D_claire_sc4_layer4x5x6x7_relu_growthRate12_with_shape_gamma10_shearlet.hdf5  SNR= 20 MEAN_ERR= 0.09723227450885938 MEDIAN_ERR= 0.09723227450885938\n\nShapeNet2D_claire_sc4_layer4x5x6x7_relu_growthRate12_with_shape_gamma1_shearlet.hdf5  SNR= 20 MEAN_ERR= 0.09366036723347601 MEDIAN_ERR= 0.09366036723347601\nShapeNet2D_claire_sc4_layer4x5x6x7_relu_gro
# ...

# %%
gamma=[0,0.001,0.002,0.004,0.01]
gamma_restart=[0,0.0001,0.001,0.01]

# %%
plt.plot(gamma,gamma_list[:,0])
plt.legend(('SNR=20'))
plt.figure()
plt.plot(gamma,gamma_list[:,1])
plt.legend(('SNR=40'))
plt.figure()
plt.plot(gamma,gamma_list[:,2])
plt.legend(('SNR=60'))
plt.figure()
plt.plot(gamma,gamma_list[:,3])
plt.legend(('SNR=80'))
plt.figure()
plt.plot(gamma,gamma_list[:,4])
plt.legend(('SNR=100'))

# %%
plt.plot(gamma_restart,gamma_restart_list[:,0])
plt.legend(('SNR=20'))
plt.figure()
plt.plot(gamma_restart,gamma_restart_list[:,1])
plt.legend(('SNR=40'))
plt.figure()
plt.plot(gamma_restart,gamma_restart_list[:,2])
plt.legend(('SNR=60'))
plt.figure()
plt.plot(gamma_restart,gamma_restart_list[:,3])
plt.legend(('SNR=80'))
plt.figure()
plt.plot(gamma_restart,gamma_restart_list[:,4])
plt.legend(('SNR=100'))

# %%
from astropy.io import fits as fits
from matplotlib import pyplot as plt
import matplotlib
import numpy as np

## Set up the sys.path in order to be able to import our modules
import os
import sys
module_path = os.path.abspath(os.path.join('../python'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
from DeepDeconv.utils.data_utils import add_noise


matplotlib.rcParams['figure.figsize']=[12,8]

# %%
write_path="/data/DeepDeconv/benchmark/claire/"
testset_file = 'image-shfl-0-multihdu.fits' #image of 10000 galaxies used for testing
# Input the hdf5 file, here we load a network trained on Tikhonov
net_path= '/home/cben-ali/Programs/deep-deconv/tutorials/'
net_file = 'DeconvNet_tuto_copy.hdf5' #network to analyse
net_root=net_file.replace('.hdf5','')
target_name=testset_file.replace('.fits','-target_fwhm0p07.fits')#Image collecting all targets
#The following is the data directory
data_directory = '/data/DeepDeconv/data/vsc_euclidpsfs/'

# Input the file containing the galaxies and psfs for testing
testset_path = '/data/DeepDeconv/data/vsc_euclidpsfs/reshuffle/'
testset_file = 'image-shfl-00-multihdu_only_target.fits'
win_file='Gaussian_Window/Gaussian_window_claire_00.fits'

noiseless_img_hdu = 0
psf_hdu = 1
targets_hdu = 2

#which list of networks we want to process
net_file_list=[
               'ShapeNet2D_FCS_claire_sc4_layer4x5x6x7_relu_growthRate12_test_ref_restart.hdf5']

#which SNR we want to investigate
SNR_list_sim=[20,40,60,80,100]#all of them:[20,40,60,80,100]

# %%
gauss_win=fits.getdata(testset_path+win_file,0)
target_win=fits.getdata(testset_path+'new_targets/'+'image-shfl-00-multihdu_newtar.fits',2)
target=fits.getdata(testset_path+testset_file,0)

plt.imshow(gauss_win[0:384,0:384], vmin=0, vmax=0.5)
plt.figure()
plt.imshow(target_win[0:384,0:384], vmin=0, vmax=0.5)
plt.figure()
plt.imshow(target[0:384,0:384], vmin=0, vmax=0.5)
plt.figure()

# %%
temp=np.zeros((10000,96,96))
temp1=np.zeros((10000,96,96))
temp1[:,28:69,28:69]=np.load('/data/DeepDeconv/sf_code/output/FCS_Euclid_10000_SNR100_lowr.npy_primal.npy')

plt.imshow(temp1[100])

# %%
# %matplotlib inline
plt.rcParams['figure.figsize']=[10,8]

# %%
test_data[114]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-46b7cd20e8e1> in <module>
# ----> 1 test_data[114]
#
# NameError: name 'test_data' is not defined

# %%
from DeepDeconv.utils.batch_utils import get_batch_from_fits
deconv_mode='TIKHONOV'
risktype=None
reg=None
tol=1e-12
reg_frac=1.0
SNR_sim=40

test_data, target_data, weights_data= get_batch_from_fits(testset_path+'new_targets/'+'image-shfl-00-multihdu_newtar.fits', 
                                                                      idx_list=np.arange(10000), SNR=SNR_sim,
                                                                      noiseless_img_hdu=noiseless_img_hdu,
                                                                      targets_hdu=targets_hdu,
                                                                      psf_hdu=psf_hdu, image_dim=96, 
                                                                      image_per_row=100, 
                                                                      deconv_mode=deconv_mode,
                                                                      risktype=risktype,reg=reg,
                                                                      tol=tol,reg_frac=reg_frac,
                                                                      shearlet=True)

# %%
test_data20, target_data, weights_data= get_batch_from_fits(testset_path+'new_targets/'+'image-shfl-00-multihdu_newtar.fits', 
                                                                      idx_list=np.arange(10000), SNR=20,
                                                                      noiseless_img_hdu=noiseless_img_hdu,
                                                                      targets_hdu=targets_hdu,
                                                                      psf_hdu=psf_hdu, image_dim=96, 
                                                                      image_per_row=100, 
                                                                      deconv_mode=deconv_mode,
                                                                      risktype=risktype,reg=reg,
                                                                      tol=tol,reg_frac=reg_frac,
                                                                      shearlet=True)

test_data60, target_data, weights_data= get_batch_from_fits(testset_path+'new_targets/'+'image-shfl-00-multihdu_newtar.fits', 
                                                                      idx_list=np.arange(10000), SNR=60,
                                                                      noiseless_img_hdu=noiseless_img_hdu,
                                                                      targets_hdu=targets_hdu,
                                                                      psf_hdu=psf_hdu, image_dim=96, 
                                                                      image_per_row=100, 
                                                                      deconv_mode=deconv_mode,
                                                                      risktype=risktype,reg=reg,
                                                                      tol=tol,reg_frac=reg_frac,
                                                                      shearlet=True)

test_data80, target_data, weights_data= get_batch_from_fits(testset_path+'new_targets/'+'image-shfl-00-multihdu_newtar.fits', 
                                                                      idx_list=np.arange(10000), SNR=80,
                                                                      noiseless_img_hdu=noiseless_img_hdu,
                                                                      targets_hdu=targets_hdu,
                                                                      psf_hdu=psf_hdu, image_dim=96, 
                                                                      image_per_row=100, 
                                                                      deconv_mode=deconv_mode,
                                                                      risktype=risktype,reg=reg,
                                                                      tol=tol,reg_frac=reg_frac,
                                                                      shearlet=True)

test_data100, target_data, weights_data= get_batch_from_fits(testset_path+'new_targets/'+'image-shfl-00-multihdu_newtar.fits', 
                                                                      idx_list=np.arange(10000), SNR=100,
                                                                      noiseless_img_hdu=noiseless_img_hdu,
                                                                      targets_hdu=targets_hdu,
                                                                      psf_hdu=psf_hdu, image_dim=96, 
                                                                      image_per_row=100, 
                                                                      deconv_mode=deconv_mode,
                                                                      risktype=risktype,reg=reg,
                                                                      tol=tol,reg_frac=reg_frac,
                                                                      shearlet=True)

# %%
noiseless_img_hdu = 0
psf_hdu = 1
targets_hdu = 2
win_hdu=0

im0=fits.getdata("/data/DeepDeconv/data/vsc_euclidpsfs/reshuffle/new_targets/image-shfl-00-multihdu_newtar.fits",noiseless_img_hdu)
target=fits.getdata("/data/DeepDeconv/data/vsc_euclidpsfs/reshuffle/new_targets/image-shfl-00-multihdu_newtar.fits",targets_hdu)
observation=add_noise(im0[96:96*2,0:96],SNR=20)
old_tar=fits.getdata("/data/DeepDeconv/data/vsc_euclidpsfs/reshuffle/image-shfl-00-multihdu.fits",targets_hdu)
pred=fits.getdata(write_path+'images/'+'image-shfl-00-multihdu_newtar-ShapeNet2D_claire_sc4_layer4x5x6x7_relu_growthRate12_with_shape_gamma0.001_newtar_gfiles_testSNR20.fits')
plt.figure(2)

#plt.imshow(old_tar[96*1:96*16,96*0:96*10],vmin=0,vmax=0.3)
#96*76:96*77,96*10:96*11
#96*25:96*26,96*39:96*20
#96:96*5,5568:5664+96*4
plt.figure(1)
plt.subplot(221)
plt.imshow(old_tar[96:96*2,0:96],vmin=0,vmax=0.25)
plt.axis('off')
plt.colorbar()
plt.title('Target') 
plt.subplot(222)
plt.imshow(observation[0],vmin=0,vmax=0.25)
plt.axis('off')
plt.colorbar()
plt.title('Observation')
plt.subplot(223)
plt.imshow(test_data20[100,:,:,0],vmin=0,vmax=0.25)
plt.axis('off')
plt.colorbar()
plt.title('Tikhonov output')
plt.subplot(224)
plt.imshow(pred[96:96*2,0:96],vmin=0,vmax=0.25)
plt.axis('off')
plt.colorbar()
plt.title('Prediction')
# Out:
# Text(0.5, 1.0, 'Prediction')

# %%
noiseless_img_hdu = 0
psf_hdu = 1
targets_hdu = 2
win_hdu=0

im0=fits.getdata("/data/DeepDeconv/data/vsc_euclidpsfs/reshuffle/new_targets/image-shfl-00-multihdu_newtar.fits",noiseless_img_hdu)
target=fits.getdata("/data/DeepDeconv/data/vsc_euclidpsfs/reshuffle/new_targets/image-shfl-00-multihdu_newtar.fits",targets_hdu)
observation=add_noise(im0[96:96*2,0:96],SNR=100)
old_tar=fits.getdata("/data/DeepDeconv/data/vsc_euclidpsfs/reshuffle/image-shfl-00-multihdu.fits",targets_hdu)
pred=fits.getdata(write_path+'images/'+'image-shfl-00-multihdu_newtar-ShapeNet2D_claire_sc4_layer4x5x6x7_relu_growthRate12_with_shape_gamma0.001_newtar_gfiles_testSNR100.fits')
plt.figure(2)

#plt.imshow(old_tar[96*1:96*16,96*0:96*10],vmin=0,vmax=0.3)
#96*76:96*77,96*10:96*11
#96*25:96*26,96*39:96*40
#96:96*5,5568:5664+96*4
plt.figure(1)
plt.subplot(221)
plt.imshow(old_tar[96:96*2,0:96],vmin=0,vmax=0.2)
plt.axis('off')
plt.colorbar()
plt.title('Target') 
plt.subplot(222)
plt.imshow(observation[0],vmin=0,vmax=0.25)
plt.axis('off')
plt.colorbar()
plt.title('Observation')
plt.subplot(223)
plt.imshow(test_data100[100,:,:,0],vmin=0,vmax=0.25)
plt.axis('off')
plt.colorbar()
plt.title('Tikhonov output')
plt.subplot(224)
plt.imshow(pred[96:96*2,0:96],vmin=0,vmax=0.2)
plt.axis('off')
plt.colorbar()
plt.title('Prediction')
# Out:
# Text(0.5, 1.0, 'Prediction')

# %%
noiseless_img_hdu = 0
psf_hdu = 1
targets_hdu = 2
win_hdu=0

im0=fits.getdata("/data/DeepDeconv/data/vsc_euclidpsfs/reshuffle/new_targets/image-shfl-00-multihdu_newtar.fits",noiseless_img_hdu)
target=fits.getdata("/data/DeepDeconv/data/vsc_euclidpsfs/reshuffle/new_targets/image-shfl-00-multihdu_newtar.fits",targets_hdu)
observation=add_noise(im0[96:96*2,0:96],SNR=40)
old_tar=fits.getdata("/data/DeepDeconv/data/vsc_euclidpsfs/reshuffle/image-shfl-00-multihdu.fits",targets_hdu)
pred=fits.getdata(write_path+'images/'+'image-shfl-00-multihdu_newtar-ShapeNet2D_claire_sc4_layer4x5x6x7_relu_growthRate12_with_shape_gamma0.001_newtar_gfiles_testSNR40.fits')
plt.figure(2)

#plt.imshow(old_tar[96*1:96*16,96*0:96*10],vmin=0,vmax=0.3)
#96*76:96*77,96*10:96*11
#96*25:96*26,96*39:96*40
#96:96*5,5568:5664+96*4
plt.figure(1)
plt.subplot(221)
plt.imshow(old_tar[96:96*2,0:96],vmin=0,vmax=0.25)
plt.axis('off')
plt.colorbar()
plt.title('Target') 
plt.subplot(222)
plt.imshow(observation[0],vmin=0,vmax=0.25)
plt.axis('off')
plt.colorbar()
plt.title('Observation')
plt.subplot(223)
plt.imshow(test_data[100,:,:,0],vmin=0,vmax=0.25)
plt.axis('off')
plt.colorbar()
plt.title('Tikhonov output')
plt.subplot(224)
plt.imshow(pred[96:96*2,0:96],vmin=0,vmax=0.25)
plt.axis('off')
plt.colorbar()
plt.title('Prediction')
# Out:
# Text(0.5, 1.0, 'Prediction')

# %%
# %matplotlib inline
plt.rcParams['figure.figsize']=[27,15]

noiseless_img_hdu = 0
psf_hdu = 1
targets_hdu = 2
win_hdu=0
temp=np.zeros((10000,96,96))
temp1=np.zeros((10000,96,96))
SNR_sim=100
target=fits.getdata("/data/DeepDeconv/benchmark/claire/images/image-shfl-0-multihdu-target_fwhm0p07.fits")
window=fits.getdata("/data/DeepDeconv/data/vsc_euclidpsfs/reshuffle/new_targets/image-shfl-00-multihdu_newtar.fits",targets_hdu)
im0=fits.getdata("/data/DeepDeconv/data/vsc_euclidpsfs/reshuffle/new_targets/image-shfl-00-multihdu_newtar.fits",noiseless_img_hdu)
observation=add_noise(im0[96:96*2,0:96],SNR=100)
temp[:,28:69,28:69]=np.load('/data/DeepDeconv/sf_code/output/FCS_Euclid_10000_SNR100_sparse.npy_primal.npy')
temp1[:,28:69,28:69]=np.load('/data/DeepDeconv/sf_code/output/FCS_Euclid_10000_SNR100_lowr.npy_primal.npy')
oscar=np.load(write_path+'images/'+'mosaic_OSCAR_RIPdeconv.npy')
shear=fits.getdata("/data/DeepDeconv/benchmark/claire/images/image-shfl-00-multihdu_newtar-ShapeNet2D_claire_sc4_layer4x5x6x7_relu_growthRate12_with_shape_gamma0.1_shearlet_testSNR100.fits")

#net1=fits.getdata(write_path+'images/'+
 #                 'image-shfl-0-multihdu-ShapeNet2D_FCS_claire_sc4_layer4x5x6x7_relu_growthRate12_gamma0.001_restart_testSNR100.fits')
#96*76:96*77,96*10:96*11
#96*25:96*26,96*39:96*40
#96:96*5,5568:5664+96*4
#96*29:96*30,96*73:96*74

net_ref=fits.getdata('/data/DeepDeconv/benchmark/claire/images/image-shfl-00-multihdu_newtar-ShapeNet2D_claire_sc4_layer4x5x6x7_relu_growthRate12_with_shape_gamma0_shearlet_testSNR100.fits')
window=fits.getdata('/data/DeepDeconv/benchmark/claire/images/image-shfl-00-multihdu_newtar-ShapeNet2D_FCS_claire_sc4_layer4x5x6x7_relu_growthRate12_test_ref_restart_newtar_gfiles_testSNR100.fits')



plt.figure(1)
plt.subplot(181)
plt.imshow(target[96:96*2,0:96],vmin=0,vmax=0.3)
plt.axis('off')
plt.title('Target')
plt.colorbar(shrink=0.16)
plt.subplot(182)
plt.imshow(observation[0],vmin=0,vmax=0.3)
plt.axis('off')
plt.title('Observation')
plt.colorbar(shrink=0.16)
plt.subplot(183)
plt.imshow(temp[100],vmin=0,vmax=0.3)
plt.axis('off')
plt.title('Sparse')
plt.colorbar(shrink=0.16)
plt.subplot(184)
plt.imshow(temp1[100],vmin=0,vmax=0.3)
plt.axis('off')
plt.title('Low rank')
plt.colorbar(shrink=0.16)
plt.subplot(185)
plt.imshow(net_ref[96:96*2,0:96],vmin=0,vmax=0.3)
plt.axis('off')
plt.title('Tikhonov+DNN')
plt.colorbar(shrink=0.16)
plt.subplot(186)
plt.imshow(oscar[96:96*2,0:96],vmin=0,vmax=0.3)
plt.axis('off')
plt.title('OSCAR')
plt.colorbar(shrink=0.16)
plt.subplot(187)
plt.imshow(net_ref[96:96*2,0:96],vmin=0,vmax=0.3)
plt.axis('off')
plt.title('Tikhonov+Window')
plt.colorbar(shrink=0.16)
plt.subplot(188)
plt.imshow(net_ref[96:96*2,0:96],vmin=0,vmax=0.3)
plt.axis('off')
plt.title('Tikhonov+Shearlet')
plt.colorbar(shrink=0.16)

# %%
target=fits.getdata("/data/DeepDeconv/benchmark/claire/images/image-shfl-0-multihdu-target_fwhm0p07.fits")
plt.figure(1)
plt.imshow(target[0:96*3,0:96*6],vmin=0,vmax=0.5)
plt.axis('off')

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
shear_gamma_0_SNR40=np.array([0.07576374467876852, 0.07532403412159726, 0.07520641431342774, 0.07545750219527045, 0.07504490666459994, 
                              0.07606483205786936, 0.0758873267723308, 0.07482732092413913, 0.07596297767164631, 0.0750135278958918])

shear_gamma_0_SNR60=np.array([0.0539008603384461, 0.05413786642949325, 0.054752252474810095, 0.05430043199648859, 0.05424916034222922,
                              0.053737365326045616, 0.053518468945946744, 0.05429639586314915, 0.05415533615206673, 0.05373703200010899])

shear_gamma_0_SNR80=np.array([0.04273480432425484, 0.04268087900574484, 0.0423991920534825, 0.04255703083584754, 0.0425109139877531, 
                              0.042516232777667695, 0.04290220801709391, 0.042457181786287795, 0.04300151288379675, 0.04333182558784954])

shear_gamma_0_SNR100=np.array([0.03633461093848338, 0.03634304925882992, 0.03624075720660885, 0.03582781012157378, 0.03616154555485418,
                              0.03559248098870418, 0.03616126316964029, 0.03556754649580509, 0.036582183777798795, 0.03608229407492565])

# %%
#gamma=1
shear_gamma_1_SNR20=np.array([0.13021794836493106, 0.12777866850005687, 0.1298457850859413, 0.13019827458627606, 0.12978442892116174,
                              0.1261641127836319, 0.13074317717972755, 0.12722245452544353, 0.12922394108077376, 0.12855220015151567])

shear_gamma_1_SNR40=np.array([0.07479367296934926, 0.07446177457973789, 0.07401549462738341, 0.07415813663450324, 0.0736779178491225,
                              0.07531214168524919, 0.07488940362305195, 0.07365485941176435, 0.07456217212237713, 0.07406793250295035])

shear_gamma_1_SNR60=np.array([0.05332992675588963, 0.05330011898502548, 0.05349383704980915, 0.05367971174654313, 0.05289402970465841,
                              0.05306205693969198, 0.0531141782760918, 0.053373915386111484, 0.053697499008817075, 0.053442636467511864])

shear_gamma_1_SNR80=np.array([0.04215404035827326, 0.04216948977522077, 0.042347141867864375, 0.04209437827079693, 0.04242431889741495,
                              0.04254493511846766, 0.04253767650578755, 0.042753171979593725, 0.04301312557766161, 0.0431708635659247])

shear_gamma_1_SNR100=np.array([0.0362526105370711, 0.03616447260711627, 0.036411318641083865, 0.035923025756842863, 0.035886897499939764, 
                               0.03588025713238187, 0.03552710157236148, 0.035809404199545626, 0.03655615589746096, 0.035923448876309896])

# %%
np.array(big_pixerr)[:,3]
# Out:
# array([0.09457676, 0.05672214, 0.04420749, 0.03776441, 0.03373805])

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1.inset_locator import zoomed_inset_axes
from mpl_toolkits.axes_grid1.inset_locator import mark_inset

matplotlib.rcParams["legend.markerscale"] = 1.0

shear_gamma_0p1_SNR20_mean=np.mean(shear_gamma_0p1_SNR20)
shear_gamma_0p1_SNR40_mean=np.mean(shear_gamma_0p1_SNR40)
shear_gamma_0p1_SNR60_mean=np.mean(shear_gamma_0p1_SNR60)
shear_gamma_0p1_SNR80_mean=np.mean(shear_gamma_0p1_SNR80)
shear_gamma_0p1_SNR100_mean=np.mean(shear_gamma_0p1_SNR100)

SNR=[20,40,60,80,100]

gamma0p1=np.array(big_pixerr)[:,3]
gamma0=np.array(big_pixerr)[:,0]
sparse=[0.306,0.221, 0.196, 0.180, 0.173]

lowrank=[0.198,0.164,0.152,0.144,0.141]

#plt.plot(SNR,sparse,SNR,lowrank,SNR,gamma0,SNR,gamma0p1)

 
  

  
# You typically want your plot to be ~1.33x wider than tall. This plot is a rare    
# exception because of the number of lines being plotted on it.    
# Common sizes: (10, 7.5) and (12, 9)    
#plt.figure(figsize=(10, 20))    
  
# Remove the plot frame lines. They are unnecessary chartjunk.    
ax = plt.subplot(111)    
ax.spines["top"].set_visible(False)    
ax.spines["bottom"].set_visible(False)    
ax.spines["right"].set_visible(False)    
ax.spines["left"].set_visible(False)    



plt.plot(SNR,sparse,'C0',SNR,lowrank,'C7',SNR,gamma0,'C9',SNR,gamma0p1,'k--',marker='p')

plt.xlabel('SNR')
plt.ylabel('Pixel error')
plt.legend(('Sparsity','Low-rank','Tikhonov+DNN','Tikhonov + shape constraint'),)


# Remove the tick marks; they are unnecessary with the tick lines we just plotted.    
plt.tick_params(axis="both", which="both", bottom="off", top="off",    
                labelbottom="on", left="off", right="off", labelleft="on") 

for y in [0,0.05,0.1,0.15,0.2,0.25,0.3]:    
    plt.plot(range(20,100), [y] * len(range(20,100)), '--', lw=0.5, color="black", alpha=0.3)

# %%
print(np.array(big_pixerr)[:,0],np.array(big_pixerr)[:,3])
# Out:
# [0.09599639 0.05729129 0.04456603 0.03793679 0.03376672] [0.09457676 0.05672214 0.04420749 0.03776441 0.03373805]

# %%
shear_gamma_0p1_SNR20_mean=np.mean(shear_gamma_0p1_SNR20)
shear_gamma_0p1_SNR40_mean=np.mean(shear_gamma_0p1_SNR40)
shear_gamma_0p1_SNR60_mean=np.mean(shear_gamma_0p1_SNR60)
shear_gamma_0p1_SNR80_mean=np.mean(shear_gamma_0p1_SNR80)
shear_gamma_0p1_SNR100_mean=np.mean(shear_gamma_0p1_SNR100)

shear_gamma_0_SNR20_mean=np.mean(shear_gamma_0_SNR20)
shear_gamma_0_SNR40_mean=np.mean(shear_gamma_0_SNR40)
shear_gamma_0_SNR60_mean=np.mean(shear_gamma_0_SNR60)
shear_gamma_0_SNR80_mean=np.mean(shear_gamma_0_SNR80)
shear_gamma_0_SNR100_mean=np.mean(shear_gamma_0_SNR100)

SNR=[20,40,60,80,100]

gamma0p1=[shear_gamma_0p1_SNR20_mean,shear_gamma_0p1_SNR40_mean,shear_gamma_0p1_SNR60_mean,shear_gamma_0p1_SNR80_mean,shear_gamma_0p1_SNR100_mean]
                 
sparse=[0.150,
0.091,
0.070,
0.059,
0.053]

lowrank=[0.149,
0.089,
0.076,
0.063,
0.052]

gamma0=[shear_gamma_0_SNR20_mean,shear_gamma_0_SNR40_mean,shear_gamma_0_SNR60_mean,shear_gamma_0_SNR80_mean,shear_gamma_0_SNR100_mean]

  
# You typically want your plot to be ~1.33x wider than tall. This plot is a rare    
# exception because of the number of lines being plotted on it.    
# Common sizes: (10, 7.5) and (12, 9)    
#plt.figure(figsize=(10, 20))    
  
# Remove the plot frame lines. They are unnecessary chartjunk.    
ax = plt.subplot(111)    
ax.spines["top"].set_visible(False)    
ax.spines["bottom"].set_visible(False)    
ax.spines["right"].set_visible(False)    
ax.spines["left"].set_visible(False)    
  


plt.plot(SNR,sparse,'C0',SNR,lowrank,'C7',SNR,gamma0,'C9',SNR,gamma0p1,'k',marker='p')
plt.xlabel('SNR')
plt.ylabel('Ellipticity error')
plt.legend(('Sparsity','Low-rank','Tikhonov+DNN','Tikhonov + shape constraint'))
# Remove the tick marks; they are unnecessary with the tick lines we just plotted.    
plt.tick_params(axis="both", which="both", bottom="off", top="off",    
                labelbottom="on", left="off", right="off", labelleft="on") 
for y in [0.02,0.04,0.06,0.08,0.1,0.12,0.14]:    
    plt.plot(range(20,100), [y] * len(range(20,100)), "--", lw=0.5, color="black", alpha=0.3)

# %%
print(gamma0p1,gamma0)
# Out:
# [0.12833493025931259, 0.07365084443645564, 0.052888295040037225, 0.04183189323676388, 0.03532975919770042] [0.13091077038396648, 0.07545525872955412, 0.054078516986878454, 0.042709178125977854, 0.03608935415872241]

# %%
shear_gamma_0_SNR20_mean=np.mean(shear_gamma_0_SNR20)
shear_gamma_0_SNR40_mean=np.mean(shear_gamma_0_SNR40)
shear_gamma_0_SNR60_mean=np.mean(shear_gamma_0_SNR60)
shear_gamma_0_SNR80_mean=np.mean(shear_gamma_0_SNR80)
shear_gamma_0_SNR100_mean=np.mean(shear_gamma_0_SNR100)

shear_gamma_0p01_SNR20_mean=np.mean(shear_gamma_0p01_SNR20)
shear_gamma_0p01_SNR40_mean=np.mean(shear_gamma_0p01_SNR40)
shear_gamma_0p01_SNR60_mean=np.mean(shear_gamma_0p01_SNR60)
shear_gamma_0p01_SNR80_mean=np.mean(shear_gamma_0p01_SNR80)
shear_gamma_0p01_SNR100_mean=np.mean(shear_gamma_0p01_SNR100)

shear_gamma_0p05_SNR20_mean=np.mean(shear_gamma_0p05_SNR20)
shear_gamma_0p05_SNR40_mean=np.mean(shear_gamma_0p05_SNR40)
shear_gamma_0p05_SNR60_mean=np.mean(shear_gamma_0p05_SNR60)
shear_gamma_0p05_SNR80_mean=np.mean(shear_gamma_0p05_SNR80)
shear_gamma_0p05_SNR100_mean=np.mean(shear_gamma_0p05_SNR100)

shear_gamma_0p1_SNR20_mean=np.mean(shear_gamma_0p1_SNR20)
shear_gamma_0p1_SNR40_mean=np.mean(shear_gamma_0p1_SNR40)
shear_gamma_0p1_SNR60_mean=np.mean(shear_gamma_0p1_SNR60)
shear_gamma_0p1_SNR80_mean=np.mean(shear_gamma_0p1_SNR80)
shear_gamma_0p1_SNR100_mean=np.mean(shear_gamma_0p1_SNR100)

shear_gamma_0p5_SNR20_mean=np.mean(shear_gamma_0p5_SNR20)
shear_gamma_0p5_SNR40_mean=np.mean(shear_gamma_0p5_SNR40)
shear_gamma_0p5_SNR60_mean=np.mean(shear_gamma_0p5_SNR60)
shear_gamma_0p5_SNR80_mean=np.mean(shear_gamma_0p5_SNR80)
shear_gamma_0p5_SNR100_mean=np.mean(shear_gamma_0p5_SNR100)

shear_gamma_1_SNR20_mean=np.mean(shear_gamma_1_SNR20)
shear_gamma_1_SNR40_mean=np.mean(shear_gamma_1_SNR40)
shear_gamma_1_SNR60_mean=np.mean(shear_gamma_1_SNR60)
shear_gamma_1_SNR80_mean=np.mean(shear_gamma_1_SNR80)
shear_gamma_1_SNR100_mean=np.mean(shear_gamma_1_SNR100)

shear_gamma_5_SNR20_mean=np.mean(shear_gamma_5_SNR20)
shear_gamma_5_SNR40_mean=np.mean(shear_gamma_5_SNR40)
shear_gamma_5_SNR60_mean=np.mean(shear_gamma_5_SNR60)
shear_gamma_5_SNR80_mean=np.mean(shear_gamma_5_SNR80)
shear_gamma_5_SNR100_mean=np.mean(shear_gamma_5_SNR100)

shear_gamma_10_SNR20_mean=np.mean(shear_gamma_10_SNR20)
shear_gamma_10_SNR40_mean=np.mean(shear_gamma_10_SNR40)
shear_gamma_10_SNR60_mean=np.mean(shear_gamma_10_SNR60)
shear_gamma_10_SNR80_mean=np.mean(shear_gamma_10_SNR80)
shear_gamma_10_SNR100_mean=np.mean(shear_gamma_10_SNR100)

shear_gamma_20_SNR20_mean=np.mean(shear_gamma_20_SNR20)
shear_gamma_20_SNR40_mean=np.mean(shear_gamma_20_SNR40)
shear_gamma_20_SNR60_mean=np.mean(shear_gamma_20_SNR60)
shear_gamma_20_SNR80_mean=np.mean(shear_gamma_20_SNR80)
shear_gamma_20_SNR100_mean=np.mean(shear_gamma_20_SNR100)

shear_gamma_50_SNR20_mean=np.mean(shear_gamma_50_SNR20)
shear_gamma_50_SNR40_mean=np.mean(shear_gamma_50_SNR40)
shear_gamma_50_SNR60_mean=np.mean(shear_gamma_50_SNR60)
shear_gamma_50_SNR80_mean=np.mean(shear_gamma_50_SNR80)
shear_gamma_50_SNR100_mean=np.mean(shear_gamma_50_SNR100)

shear_gamma_100_SNR20_mean=np.mean(shear_gamma_100_SNR20)
shear_gamma_100_SNR40_mean=np.mean(shear_gamma_100_SNR40)
shear_gamma_100_SNR60_mean=np.mean(shear_gamma_100_SNR60)
shear_gamma_100_SNR80_mean=np.mean(shear_gamma_100_SNR80)
shear_gamma_100_SNR100_mean=np.mean(shear_gamma_100_SNR100)

shear_gamma_500_SNR20_mean=np.mean(shear_gamma_500_SNR20)
shear_gamma_500_SNR40_mean=np.mean(shear_gamma_500_SNR40)
shear_gamma_500_SNR60_mean=np.mean(shear_gamma_500_SNR60)
shear_gamma_500_SNR80_mean=np.mean(shear_gamma_500_SNR80)
shear_gamma_500_SNR100_mean=np.mean(shear_gamma_500_SNR100)

mean20=[shear_gamma_0_SNR20_mean,shear_gamma_0p01_SNR20_mean,shear_gamma_0p05_SNR20_mean,shear_gamma_0p1_SNR20_mean,shear_gamma_0p5_SNR20_mean,shear_gamma_1_SNR20_mean,shear_gamma_5_SNR20_mean,shear_gamma_10_SNR20_mean,shear_gamma_20_SNR20_mean,shear_gamma_50_SNR20_mean,shear_gamma_100_SNR20_mean,shear_gamma_500_SNR20_mean] 
mean40=[shear_gamma_0_SNR40_mean,shear_gamma_0p01_SNR40_mean,shear_gamma_0p05_SNR40_mean,shear_gamma_0p1_SNR40_mean,shear_gamma_0p5_SNR40_mean,shear_gamma_1_SNR40_mean,shear_gamma_5_SNR40_mean,shear_gamma_10_SNR40_mean,shear_gamma_20_SNR40_mean,shear_gamma_50_SNR40_mean,shear_gamma_100_SNR40_mean,shear_gamma_500_SNR40_mean] 
mean60=[shear_gamma_0_SNR60_mean,shear_gamma_0p01_SNR60_mean,shear_gamma_0p05_SNR60_mean,shear_gamma_0p1_SNR60_mean,shear_gamma_0p5_SNR60_mean,shear_gamma_1_SNR60_mean,shear_gamma_5_SNR60_mean,shear_gamma_10_SNR60_mean,shear_gamma_20_SNR60_mean,shear_gamma_50_SNR60_mean,shear_gamma_100_SNR60_mean,shear_gamma_500_SNR60_mean] 
mean80=[shear_gamma_0_SNR80_mean,shear_gamma_0p01_SNR80_mean,shear_gamma_0p05_SNR80_mean,shear_gamma_0p1_SNR80_mean,shear_gamma_0p5_SNR80_mean,shear_gamma_1_SNR80_mean,shear_gamma_5_SNR80_mean,shear_gamma_10_SNR80_mean,shear_gamma_20_SNR80_mean,shear_gamma_50_SNR80_mean,shear_gamma_100_SNR80_mean,shear_gamma_500_SNR80_mean] 
mean100=[shear_gamma_0_SNR100_mean,shear_gamma_0p01_SNR100_mean,shear_gamma_0p05_SNR100_mean,shear_gamma_0p1_SNR100_mean,shear_gamma_0p5_SNR100_mean,shear_gamma_1_SNR100_mean,shear_gamma_5_SNR100_mean,shear_gamma_10_SNR100_mean,shear_gamma_20_SNR100_mean,shear_gamma_50_SNR100_mean,shear_gamma_100_SNR100_mean,shear_gamma_500_SNR100_mean] 
 
    
mean0p1=[shear_gamma_0p1_SNR20_mean,shear_gamma_0p1_SNR40_mean,shear_gamma_0p1_SNR60_mean,shear_gamma_0p1_SNR80_mean,shear_gamma_0p1_SNR100_mean]
std0p1=[shear_gamma_0p1_SNR20_std,shear_gamma_0p1_SNR40_std,shear_gamma_0p1_SNR60_std,shear_gamma_0p1_SNR80_std,shear_gamma_0p1_SNR100_std]
shear_gamma_0_SNR20_std=np.std(shear_gamma_0_SNR20)
shear_gamma_0_SNR40_std=np.std(shear_gamma_0_SNR40)
shear_gamma_0_SNR60_std=np.std(shear_gamma_0_SNR60)
shear_gamma_0_SNR80_std=np.std(shear_gamma_0_SNR80)
shear_gamma_0_SNR100_std=np.std(shear_gamma_0_SNR100)

shear_gamma_0p01_SNR20_std=np.std(shear_gamma_0p01_SNR20)
shear_gamma_0p01_SNR40_std=np.std(shear_gamma_0p01_SNR40)
shear_gamma_0p01_SNR60_std=np.std(shear_gamma_0p01_SNR60)
shear_gamma_0p01_SNR80_std=np.std(shear_gamma_0p01_SNR80)
shear_gamma_0p01_SNR100_std=np.std(shear_gamma_0p01_SNR100)

shear_gamma_0p05_SNR20_std=np.std(shear_gamma_0p05_SNR20)
shear_gamma_0p05_SNR40_std=np.std(shear_gamma_0p05_SNR40)
shear_gamma_0p05_SNR60_std=np.std(shear_gamma_0p05_SNR60)
shear_gamma_0p05_SNR80_std=np.std(shear_gamma_0p05_SNR80)
shear_gamma_0p05_SNR100_std=np.std(shear_gamma_0p05_SNR100)

shear_gamma_0p1_SNR20_std=np.std(shear_gamma_0p1_SNR20)
shear_gamma_0p1_SNR40_std=np.std(shear_gamma_0p1_SNR40)
shear_gamma_0p1_SNR60_std=np.std(shear_gamma_0p1_SNR60)
shear_gamma_0p1_SNR80_std=np.std(shear_gamma_0p1_SNR80)
shear_gamma_0p1_SNR100_std=np.std(shear_gamma_0p1_SNR100)

shear_gamma_0p5_SNR20_std=np.std(shear_gamma_0p5_SNR20)
shear_gamma_0p5_SNR40_std=np.std(shear_gamma_0p5_SNR40)
shear_gamma_0p5_SNR60_std=np.std(shear_gamma_0p5_SNR60)
shear_gamma_0p5_SNR80_std=np.std(shear_gamma_0p5_SNR80)
shear_gamma_0p5_SNR100_std=np.std(shear_gamma_0p5_SNR100)

shear_gamma_1_SNR20_std=np.std(shear_gamma_1_SNR20)
shear_gamma_1_SNR40_std=np.std(shear_gamma_1_SNR40)
shear_gamma_1_SNR60_std=np.std(shear_gamma_1_SNR60)
shear_gamma_1_SNR80_std=np.std(shear_gamma_1_SNR80)
shear_gamma_1_SNR100_std=np.std(shear_gamma_1_SNR100)

shear_gamma_5_SNR20_std=np.std(shear_gamma_5_SNR20)
shear_gamma_5_SNR40_std=np.std(shear_gamma_5_SNR40)
shear_gamma_5_SNR60_std=np.std(shear_gamma_5_SNR60)
shear_gamma_5_SNR80_std=np.std(shear_gamma_5_SNR80)
shear_gamma_5_SNR100_std=np.std(shear_gamma_5_SNR100)

shear_gamma_10_SNR20_std=np.std(shear_gamma_10_SNR20)
shear_gamma_10_SNR40_std=np.std(shear_gamma_10_SNR40)
shear_gamma_10_SNR60_std=np.std(shear_gamma_10_SNR60)
shear_gamma_10_SNR80_std=np.std(shear_gamma_10_SNR80)
shear_gamma_10_SNR100_std=np.std(shear_gamma_10_SNR100)

shear_gamma_20_SNR20_std=np.std(shear_gamma_20_SNR20)
shear_gamma_20_SNR40_std=np.std(shear_gamma_20_SNR40)
shear_gamma_20_SNR60_std=np.std(shear_gamma_20_SNR60)
shear_gamma_20_SNR80_std=np.std(shear_gamma_20_SNR80)
shear_gamma_20_SNR100_std=np.std(shear_gamma_20_SNR100)

shear_gamma_50_SNR20_std=np.std(shear_gamma_50_SNR20)
shear_gamma_50_SNR40_std=np.std(shear_gamma_50_SNR40)
shear_gamma_50_SNR60_std=np.std(shear_gamma_50_SNR60)
shear_gamma_50_SNR80_std=np.std(shear_gamma_50_SNR80)
shear_gamma_50_SNR100_std=np.std(shear_gamma_50_SNR100)

shear_gamma_100_SNR20_std=np.std(shear_gamma_100_SNR20)
shear_gamma_100_SNR40_std=np.std(shear_gamma_100_SNR40)
shear_gamma_100_SNR60_std=np.std(shear_gamma_100_SNR60)
shear_gamma_100_SNR80_std=np.std(shear_gamma_100_SNR80)
shear_gamma_100_SNR100_std=np.std(shear_gamma_100_SNR100)

shear_gamma_500_SNR20_std=np.std(shear_gamma_500_SNR20)
shear_gamma_500_SNR40_std=np.std(shear_gamma_500_SNR40)
shear_gamma_500_SNR60_std=np.std(shear_gamma_500_SNR60)
shear_gamma_500_SNR80_std=np.std(shear_gamma_500_SNR80)
shear_gamma_500_SNR100_std=np.std(shear_gamma_500_SNR100)

std20=[shear_gamma_0_SNR20_std,shear_gamma_0p01_SNR20_std,shear_gamma_0p05_SNR20_std,shear_gamma_0p1_SNR20_std,shear_gamma_0p5_SNR20_std,shear_gamma_1_SNR20_std,shear_gamma_5_SNR20_std,shear_gamma_10_SNR20_std,shear_gamma_20_SNR20_std,shear_gamma_50_SNR20_std,shear_gamma_100_SNR20_std,shear_gamma_500_SNR20_std] 
std40=[shear_gamma_0_SNR40_std,shear_gamma_0p01_SNR40_std,shear_gamma_0p05_SNR40_std,shear_gamma_0p1_SNR40_std,shear_gamma_0p5_SNR40_std,shear_gamma_1_SNR40_std,shear_gamma_5_SNR40_std,shear_gamma_10_SNR40_std,shear_gamma_20_SNR40_std,shear_gamma_50_SNR40_std,shear_gamma_100_SNR40_std,shear_gamma_500_SNR40_std] 
std60=[shear_gamma_0_SNR60_std,shear_gamma_0p01_SNR60_std,shear_gamma_0p05_SNR60_std,shear_gamma_0p1_SNR60_std,shear_gamma_0p5_SNR60_std,shear_gamma_1_SNR60_std,shear_gamma_5_SNR60_std,shear_gamma_10_SNR60_std,shear_gamma_20_SNR60_std,shear_gamma_50_SNR60_std,shear_gamma_100_SNR60_std,shear_gamma_500_SNR60_std] 
std80=[shear_gamma_0_SNR80_std,shear_gamma_0p01_SNR80_std,shear_gamma_0p05_SNR80_std,shear_gamma_0p1_SNR80_std,shear_gamma_0p5_SNR80_std,shear_gamma_1_SNR80_std,shear_gamma_5_SNR80_std,shear_gamma_10_SNR80_std,shear_gamma_20_SNR80_std,shear_gamma_50_SNR80_std,shear_gamma_100_SNR80_std,shear_gamma_500_SNR80_std] 
std100=[shear_gamma_0_SNR100_std,shear_gamma_0p01_SNR100_std,shear_gamma_0p05_SNR100_std,shear_gamma_0p1_SNR100_std,shear_gamma_0p5_SNR100_std,shear_gamma_1_SNR100_std,shear_gamma_5_SNR100_std,shear_gamma_10_SNR100_std,shear_gamma_20_SNR100_std,shear_gamma_50_SNR100_std,shear_gamma_100_SNR100_std,shear_gamma_500_SNR100_std] 

SNR=[20,40,60,80,100]
gamma=[0,0.01,0.05,0.1,0.5,1,5,10,20,50,100,500]

plt.figure()
plt.errorbar(SNR,mean0p1,std0p1,ecolor='red')
plt.xlabel('SNR')
plt.ylabel('Ellipticity error')

plt.figure()

plt.errorbar(gamma,mean20,std20,ecolor='red')
plt.xlabel('gamma')
plt.ylabel('Ellipticity error')
plt.xscale('log')
plt.figure()

plt.errorbar(gamma,mean40,std40,ecolor='red')
plt.xscale('log')
plt.xlabel('gamma')
plt.ylabel('Ellipticity error')
plt.figure()

plt.errorbar(gamma,mean60,std60,ecolor='red')
plt.xscale('log')
plt.xlabel('gamma')
plt.ylabel('Ellipticity error')
plt.figure()

plt.errorbar(gamma,mean80,std80,ecolor='red')

plt.xscale('log')
plt.xlabel('gamma')
plt.ylabel('Ellipticity error')
plt.figure()

plt.errorbar(gamma,mean100,std100,ecolor='red')
plt.xscale('log')
plt.xlabel('gamma')
plt.ylabel('Ellipticity error')

np.array([mean20,mean40,mean60,mean80,mean100])


#print(std20)
#print(std40)
#print(std60)
#rint(std80)
#print(std100)
# Out:
# array([[0.13091077, 0.13369009, 0.12886089, 0.12833493, 0.12972286,
#         0.1289731 , 0.1292492 , 0.12870003, 0.12810968, 0.1293759 ,
#         0.12925546, 0.13171178],
#        [0.07545526, 0.07613435, 0.0742452 , 0.07365084, 0.07457232,
#         0.07435935, 0.07460923, 0.07438115, 0.0737805 , 0.07411727,
#         0.07490686, 0.07536285],
#        [0.05407852, 0.0540524 , 0.0529637 , 0.0528883 , 0.05352504,
#         0.05333879, 0.05347057, 0.05349188, 0.05297805, 0.05318267,
#         0.053471  , 0.0536568 ],
#        [0.04270918, 0.04282269, 0.0418678 , 0.04183189, 0.04268919,
#         0.04252091, 0.04253444, 0.04218078, 0.04208002, 0.04244773,
#         0.04218457, 0.04230649],
#        [0.03608935, 0.03688706, 0.03550487, 0.03532976, 0.03640994,
#         0.03603347, 0.03617791, 0.03523812, 0.03610642, 0.0372022 ,
#         0.03548936, 0.0358553 ]])

# %%
net_file_list=['ShapeNet2D_claire_sc4_layer4x5x6x7_relu_growthRate12_with_shape_gamma0_shearlet.hdf5',
               'ShapeNet2D_claire_sc4_layer4x5x6x7_relu_growthRate12_with_shape_gamma0.01_shearlet.hdf5',
               'ShapeNet2D_claire_sc4_layer4x5x6x7_relu_growthRate12_with_shape_gamma0.05_shearlet.hdf5',
               'ShapeNet2D_claire_sc4_layer4x5x6x7_relu_growthRate12_with_shape_gamma0.1_shearlet.hdf5',
               'ShapeNet2D_claire_sc4_layer4x5x6x7_relu_growthRate12_with_shape_gamma0.5_shearlet.hdf5',
               'ShapeNet2D_claire_sc4_layer4x5x6x7_relu_growthRate12_with_shape_gamma1_shearlet.hdf5',
               'ShapeNet2D_claire_sc4_layer4x5x6x7_relu_growthRate12_with_shape_gamma5_shearlet.hdf5',
               'ShapeNet2D_claire_sc4_layer4x5x6x7_relu_growthRate12_with_shape_gamma10__new_shearlet.hdf5',
               'ShapeNet2D_claire_sc4_layer4x5x6x7_relu_growthRate12_with_shape_gamma20_shearlet.hdf5',
               'ShapeNet2D_claire_sc4_layer4x5x6x7_relu_growthRate12_with_shape_gamma50_shearlet.hdf5',
               'ShapeNet2D_claire_sc4_layer4x5x6x7_relu_growthRate12_with_shape_gamma100_shearlet.hdf5',
               'ShapeNet2D_claire_sc4_layer4x5x6x7_relu_growthRate12_with_shape_gamma500_shearlet.hdf5']

# %%
testset_file='image-shfl-00-multihdu_newtar.fits'
n=len(net_file_list)
pixerr={}
for net_file in range(n):
    pixerr[net_file_list[net_file]]={}
    for i in range(5):
        pixerr[net_file_list[net_file]][SNR_list_sim[i]]={}
        SNR_sim=SNR_list_sim[i]
        for j in range(10):
            if net_file==3 and j==0:
                continue
            else:
                mosaic_name=testset_file.replace('.fits','-'+net_file_list[net_file].replace('.hdf5','_testSNR{0}_iteration{1}.fits'.format(SNR_sim,j)))
                write_txt_name=write_path+'stats/'+mosaic_name.replace('.fits','_pixelerr_newwin.txt')
                err=np.loadtxt(write_txt_name)
                pixerr[net_file_list[net_file]][SNR_list_sim[i]][j]=np.median(err)

# %%
pixerr['ShapeNet2D_claire_sc4_layer4x5x6x7_relu_growthRate12_with_shape_gamma0.1_shearlet.hdf5'][20]
# Out:
# {1: 0.09433558623949548,
#  2: 0.09478077339133786,
#  3: 0.09454505367835424,
#  4: 0.09424043321005734,
#  5: 0.09423542354280641,
#  6: 0.09496879707218438,
#  7: 0.09462555272465387,
#  8: 0.09457495419637515,
#  9: 0.09488425628524769}

# %%
big_pixerr=np.array(big_pixerr)
big_pixerr
# Out:
# array([[0.09599639, 0.1014814 , 0.0963241 , 0.09457676, 0.09741489,
#         0.09320514, 0.10218813, 0.09334708, 0.09589893, 0.09498718,
#         0.09302686, 0.09932879],
#        [0.05729129, 0.05872619, 0.0573825 , 0.05672214, 0.05623679,
#         0.05641919, 0.05642992, 0.05606341, 0.05753171, 0.05637652,
#         0.05641571, 0.05852323],
#        [0.04456603, 0.04522158, 0.04454724, 0.04420749, 0.04385408,
#         0.04391904, 0.04377807, 0.04345462, 0.04471284, 0.04384616,
#         0.04383905, 0.04562257],
#        [0.03793679, 0.03856006, 0.03789425, 0.03776441, 0.03747484,
#         0.03745108, 0.03721   , 0.03692297, 0.03810804, 0.03754404,
#         0.037338  , 0.03879019],
#        [0.03376672, 0.03474848, 0.03361534, 0.03373805, 0.03352354,
#         0.03342794, 0.03320605, 0.03289717, 0.0342096 , 0.03563832,
#         0.03317697, 0.03455973]])

# %%
gamma=[0,0.01,0.05,0.1,0.5,1,5,10,20,50,100,500]
big_pixerr=[]
for SNR in SNR_list_sim:
    plot_pixerr=[]
    std_pixerr=[]
    for net_file in net_file_list:
        temp=np.zeros(10)
        for iter in range(10):
            if net_file=='ShapeNet2D_claire_sc4_layer4x5x6x7_relu_growthRate12_with_shape_gamma0.1_shearlet.hdf5' and iter==0:
                continue
            else:
                temp[iter]=pixerr[net_file][SNR][iter]
        if net_file=='ShapeNet2D_claire_sc4_layer4x5x6x7_relu_growthRate12_with_shape_gamma0.1_shearlet.hdf5':
            temp=temp[1:]
            #print(temp)
        plot_pixerr.append(np.mean(temp))
        std_pixerr.append(np.std(temp))
    plt.figure()
    plt.errorbar(gamma[0:5],plot_pixerr[0:5],std_pixerr[0:5],ecolor='red',lolims=0.001, uplims=0.5)
    plt.xlabel('gamma')
    plt.ylabel('Pixel error')
    #plt.title('Errorbar SNR{0}'.format(SNR))
    #plt.ylim(np.min(plot_pixerr)*0.8,np.max(plot_pixerr)*1.2)
    #plt.xscale('log')
    big_pixerr.append(plot_pixerr)
