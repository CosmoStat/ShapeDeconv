# %% [markdown]
# This notebook is a step by step guide about how to train a deep neural network (DNN) in the DeepDeconv framework.

# %%
## Set up the sys.path in order to be able to import our modules
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
import keras.utils
# Out:
# Using TensorFlow backend.

# %%
## extra imports to set GPU options
import tensorflow as tf
from keras import backend as k

###################################
# TensorFlow wizardry
config = tf.ConfigProto()
# Don't pre-allocate memory; allocate as-needed
config.gpu_options.allow_growth = True

# Only allow a total of half the GPU memory to be allocated
# This line is optional, don't add it unless you really need to set a limit on the memory available for your process
# For instance, if you want to train 2 DNNs on the same GPU without one overlapping the memory needed by the other
# Change the value to set the percentage of memory allocated
#config.gpu_options.per_process_gpu_memory_fraction = 0.75 
# Create a session with the above options specified.
k.tensorflow_backend.set_session(tf.Session(config=config))

# Now you can create/load your DNN

# %%
#from DeepDeconv.deepnetFCS.DeconvNet import DeconvNet

# %%
from deepnetFCS.DeconvNet_custom import DeconvNet
nb_scales = 3
nb_layers_per_block =  [3,3,3]
growth_rate=23
activation_function= 'relu' #'swish','relu'
resNet=False
layer_string='layer{0}'.format(nb_layers_per_block[0])
atrou=False

for k in range(1,len(nb_layers_per_block)):
    layer_string+='x{0}'.format(nb_layers_per_block[k])
network_name='DeconvNet2D_FCS_sc{0}_{1}_{2}_growthRate{3}'.format(nb_scales,layer_string,activation_function,growth_rate)
if atrou:
    network_name+='_atrou'
if resNet:
    network_name+='_resNet'

print("Network Name:",network_name)
    
dnn = DeconvNet(network_name = network_name, img_rows = 96, img_cols = 96, model_file='', verbose=True,
                growth_rate=growth_rate,nb_scales=nb_scales, nb_layers_per_block=nb_layers_per_block, 
             activation_function=activation_function,resNet=resNet,atrou=atrou)
# Out:
# Network Name: DeconvNet2D_FCS_sc3_layer3x3x3_relu_growthRate23
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 96, 96, 1)    0
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 96, 96, 32)   288         input_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 96, 96, 32)   128         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 96, 96, 32)   0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_51 (SeparableC (None, 96, 96, 23)   1024        activation_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 96, 96, 23)   92          separable_conv2d_51[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 96, 96, 23)   0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_52 (SeparableC (None, 96, 96, 23)   736         activation_59[0][0]
# __________________________________________________________________________________________________
# concatenate_49 (Concatenate)    (None, 96, 96, 46)   0           separable_conv2d_51[0][0]
#                                                                  separable_conv2d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 96, 96, 46)   184         concatenate_49[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 96, 96, 46)   0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_53 (SeparableC (None, 96, 96, 23)   1472        activation_60[0][0]
# __________________________________________________________________________________________________
# concatenate_50 (Concatenate)    (None, 96, 96, 69)   0           concatenate_49[0][0]
#                                                                  separable_conv2d_53[0][0]
# __________________________________________________________________________________________________
# concatenate_51 (Concatenate)    (None, 96, 96, 101)  0           conv2d_15[0][0]
#                                                                  concatenate_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 96, 96, 101)  404         concatenate_51[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 96, 96, 101)  0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 96, 96, 101)  10201       activation_61[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_6 (AveragePoo (None, 48, 48, 101)  0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 48, 48, 101)  404         average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 48, 48, 101)  0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_54 (SeparableC (None, 48, 48, 23)   3232        activation_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 48, 48, 23)   92          separable_conv2d_54[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 48, 48, 23)   0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_55 (SeparableC (None, 48, 48, 23)   736         activation_63[0][0]
# __________________________________________________________________________________________________
# concatenate_52 (Concatenate)    (None, 48, 48, 46)   0           separable_conv2d_54[0][0]
#                                                                  separable_conv2d_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 48, 48, 46)   184         concatenate_52[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 48, 48, 46)   0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_56 (SeparableC (None, 48, 48, 23)   1472        activation_64[0][0]
# __________________________________________________________________________________________________
# concatenate_53 (Concatenate)    (None, 48, 48, 69)   0           concatenate_52[0][0]
#                                                                  separable_conv2d_56[0][0]
# __________________________________________________________________________________________________
# concatenate_54 (Concatenate)    (None, 48, 48, 170)  0           average_pooling2d_6[0][0]
#                                                                  concatenate_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 48, 48, 170)  680         concatenate_54[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 48, 48, 170)  0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 48, 48, 170)  28900       activation_65[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_7 (AveragePoo (None, 24, 24, 170)  0           conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 24, 24, 170)  680         average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 24, 24, 170)  0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_57 (SeparableC (None, 24, 24, 23)   5440        activation_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 24, 24, 23)   92          separable_conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 24, 24, 23)   0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_58 (SeparableC (None, 24, 24, 23)   736         activation_67[0][0]
# __________________________________________________________________________________________________
# concatenate_55 (Concatenate)    (None, 24, 24, 46)   0           separable_conv2d_57[0][0]
#                                                                  separable_conv2d_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 24, 24, 46)   184         concatenate_55[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 24, 24, 46)   0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_59 (SeparableC (None, 24, 24, 23)   1472        activation_68[0][0]
# __________________________________________________________________________________________________
# concatenate_56 (Concatenate)    (None, 24, 24, 69)   0           concatenate_55[0][0]
#                                                                  separable_conv2d_59[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_6 (UpSampling2D)  (None, 48, 48, 69)   0           concatenate_56[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 48, 48, 69)   19113       up_sampling2d_6[0][0]
# __________________________________________________________________________________________________
# concatenate_57 (Concatenate)    (None, 48, 48, 239)  0           conv2d_18[0][0]
#                                                                  concatenate_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 48, 48, 239)  956         concatenate_57[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 48, 48, 239)  0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_60 (SeparableC (None, 48, 48, 23)   7648        activation_69[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 48, 48, 23)   92          separable_conv2d_60[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 48, 48, 23)   0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_61 (SeparableC (None, 48, 48, 23)   736         activation_70[0][0]
# __________________________________________________________________________________________________
# concatenate_58 (Concatenate)    (None, 48, 48, 46)   0           separable_conv2d_60[0][0]
#                                                                  separable_conv2d_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 48, 48, 46)   184         concatenate_58[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 48, 48, 46)   0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_62 (SeparableC (None, 48, 48, 23)   1472        activation_71[0][0]
# __________________________________________________________________________________________________
# concatenate_59 (Concatenate)    (None, 48, 48, 69)   0           concatenate_58[0][0]
#                                                                  separable_conv2d_62[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_7 (UpSampling2D)  (None, 96, 96, 69)   0           concatenate_59[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 96, 96, 69)   19113       up_sampling2d_7[0][0]
# __________________________________________________________________________________________________
# concatenate_60 (Concatenate)    (None, 96, 96, 170)  0           conv2d_19[0][0]
#                                                                  concatenate_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_72 (BatchNo (None, 96, 96, 170)  680         concatenate_60[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, 96, 96, 170)  0           batch_normalization_72[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_63 (SeparableC (None, 96, 96, 23)   5440        activation_72[0][0]
# __________________________________________________________________________________________________
# batch_normalization_73 (BatchNo (None, 96, 96, 23)   92          separable_conv2d_63[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, 96, 96, 23)   0           batch_normalization_73[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_64 (SeparableC (None, 96, 96, 23)   736         activation_73[0][0]
# __________________________________________________________________________________________________
# concatenate_61 (Concatenate)    (None, 96, 96, 46)   0           separable_conv2d_63[0][0]
#                                                                  separable_conv2d_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_74 (BatchNo (None, 96, 96, 46)   184         concatenate_61[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 96, 96, 46)   0           batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_65 (SeparableC (None, 96, 96, 23)   1472        activation_74[0][0]
# __________________________________________________________________________________________________
# concatenate_62 (Concatenate)    (None, 96, 96, 69)   0           concatenate_61[0][0]
#                                                                  separable_conv2d_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 96, 96, 69)   276         concatenate_62[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 96, 96, 69)   0           batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 96, 96, 1)    70          activation_75[0][0]
# ==================================================================================================
# Total params: 117,097
# Trainable params: 114,303
# Non-trainable params: 2,794
# __________________________________________________________________________________________________
# None

# %%
from keras.utils import plot_model
plot_model(dnn.model, to_file='{0}.png'.format(network_name),show_shapes=True)

# %%
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot

pydot_obj=model_to_dot(dnn.model,show_shapes=True,show_layer_names=False)
SVG(pydot_obj.create(prog='dot', format='svg'))

# %% [markdown]
# ## PREPROCESSING OF DATA

# %%
# from astropy.io import fits as fits
# from matplotlib import pyplot as plt
# #Input the directory containing the fits file
# data_directory = '/data/DeepDeconv/data/vsc_euclidpsfs/'

# #Retrieves the list of all the files
# import glob

# gal_files = glob.glob(data_directory+'image-0*-0.fits')
# gal_files.sort()
# print(gal_files)

# import numpy as np

# from utils.batch_utils import shuffle_new_fits

# data_reshfl_dir=data_directory+"reshuffle/"
# noiseless_img_hdu = 1
# targets_hdu = 4
# psf_hdu = 3
# rootname_reshfl=data_reshfl_dir+"image-shfl"
# np.random.seed(2012)
# shuffle_new_fits(gal_files, nb_img_per_file=10000,
#                         noiseless_img_hdu=noiseless_img_hdu, targets_hdu=targets_hdu, psf_hdu=psf_hdu,
#                         image_dim=96, image_per_row=100,rootname=rootname_reshfl)

# %%
# from astropy.io import fits as fits
# from matplotlib import pyplot as plt
# ff=fits.open(gal_files[0])
# plt.figure()
# for k in range(5):
#     plt.subplot(2,3,k+1),plt.imshow(ff[k].data[0:96,0:96])
# #HDU 0: noisy
# #HDU 1: noise free convolved with euclid PSF
# #HDU 2: noise free convolved with large PSF (gauss 0.15 FWHM)
# #HDU 3: euclid PSF
# #HDU 4: noise free convolved with target PSF (gauss 0.07 FWHM)
# plt.figure()
# plt.imshow(ff[1].data[0:96,0:96]-ff[4].data[0:96,0:96])

# %% [markdown]
# ## Training Phase

# %%
import glob
import numpy as np
from astropy.io import fits as fits
from matplotlib import pyplot as plt
data_directory = '/data/DeepDeconv/data/vsc_euclidpsfs/'

noiseSTD=None
if noiseSTD is None:
    SNR = [20,100]
    if len(SNR)==1:
        old_dnn_name=dnn.network_name
        dnn.network_name+='_reshfl_SNR{0}'.format(SNR[0])
    else:
        old_dnn_name=dnn.network_name
        dnn.network_name+='_reshfl_SNR{0}to{1}'.format(SNR[0],SNR[1])
else:
    old_dnn_name=dnn.network_name
    dnn.network_name+='_reshfl_STD{0}'.format(noiseSTD)
noiseless_img_hdu = 0
psf_hdu = 1
targets_hdu = 2
deconv_mode = 'TIKHONOV'
data_reshfl_dir=data_directory+"reshuffle/"
gal_files_shfl = glob.glob(data_reshfl_dir+'image-shfl-*-multihdu.fits')
gal_files_shfl.sort()

print(gal_files_shfl)
print(dnn.network_name)

#Train with the image-000-0.fits as validation and all the other files as training set
dnn.train_generator(gal_files_shfl[2:], gal_files_shfl[1], epochs=20, batch_size=24,
                        nb_img_per_file=10000, validation_set_size=10000,
                        noise_std=None, SNR=SNR, model_file='',
                        noiseless_img_hdu=noiseless_img_hdu, targets_hdu=targets_hdu, psf_hdu=psf_hdu,
                        image_dim=96, image_per_row=100,
                        deconv_mode=deconv_mode)

dnn.network_name=old_dnn_name
# Out:
# ['/data/DeepDeconv/data/vsc_euclidpsfs/reshuffle/image-shfl-0-multihdu.fits', '/data/DeepDeconv/data/vsc_euclidpsfs/reshuffle/image-shfl-1-multihdu.fits', '/data/DeepDeconv/data/vsc_euclidpsfs/reshuffle/image-shfl-10-multihdu.fits', '/data/DeepDeconv/data/vsc_euclidpsfs/reshuffle/image-shfl-11-multihdu.fits', '/data/DeepDeconv/data/vsc_euclidpsfs/reshuffle/image-shfl-12-multihdu.fits', '/data/DeepDeconv/data/vsc_euclidpsfs/reshuffle/image-shfl-13-multihdu.fits', '/data/DeepDeconv/data/vsc_euclidpsfs/reshuffle/image-shfl-14-multihdu.fits', '/data/DeepDeconv/data/vsc_euclidpsfs/reshuffle/image-shfl-15-multihdu.fits', '/data/DeepDeconv/data/vsc_euclidpsfs/reshuffle/image-shfl-16-multihdu.fits', '/data/DeepDeconv/data/vsc_euclidpsfs/reshuffle/image-shfl-17-multihdu.fits', '/data/DeepDeconv/data/vsc_euclidpsfs/reshuffle/image-shfl-18-multihdu.fits', '/data/DeepDeconv/data/vsc_euclidpsfs/reshuffle/image-shfl-19-multihdu.fits', '/data/DeepDeconv/data/vsc_euclidpsfs/reshuffle/image-shfl-2-multihdu.fits', '/data/DeepDeconv/data/vsc_euclidpsfs/reshuffle/image-shfl-20-multihdu.fits', '/data/DeepDeconv/data/vsc_euclidpsfs/reshuffle/image-shfl-3-multihdu.fits', '/data/DeepDeconv/data/vsc_euclidpsfs/reshuffle/image-shfl-4-multihdu.fits', '/data/DeepDeconv/data/vsc_euclidpsfs/reshuffle/image-shfl-5-multihdu.fits', '/data/DeepDeconv/data/vsc_euclidpsfs/reshuffle/image-shfl-6-multihdu.fits', '/data/DeepDeconv/data/vsc_euclidpsfs/reshuffle/image-shfl-7-multihdu.fits', '/data/DeepDeconv/data/vsc_euclidpsfs/reshuffle/image-shfl-8-multihdu.fits', '/data/DeepDeconv/data/vsc_euclidpsfs/reshuffle/image-shfl-9-multihdu.fits']
# DeconvNet2D_FCS_sc4_layer5x5x5x5_swish_growthRate12_reshfl_SNR20to100
# Model will be saved at /home/fsureau/programs/DeepDeconv/DeconvNet2D_FCS_sc4_layer5x5x5x5_swish_growthRate12_reshfl_SNR20to100.hdf5
# Memory usage for the model + one batch (GB): 2.452000
# /home/fsureau/programs/DeepDeconv/deepnet/DeepNet.py:133: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<generator..., epochs=20, validation_data=(array([[[..., verbose=1, callbacks=[<keras.ca..., steps_per_epoch=7923)`
#   callbacks=[model_checkpoint, LoggingCallback(filetxt=logfile, log=write_log)])
# Epoch 1/20
# 7923/7923 [==============================] - 8366s 1s/step - loss: 9.0276e-04 - val_loss: 2.4842e-04
#
# Epoch 00001: val_loss improved from inf to 0.00025, saving model to DeconvNet2D_FCS_sc4_layer5x5x5x5_swish_growthRate12_reshfl_SNR20to100.hdf5
# 2019-02-14_22:36:54 - Epoch: 1, val_loss: 0.000248, loss: 0.000903
# Epoch 2/20
# 7923/7923 [==============================] - 5990s 756ms/step - loss: 2.3370e-04 - val_loss: 2.2611e-04
#
# Epoch 00002: val_loss improved from 0.00025 to 0.00023, saving model to DeconvNet2D_FCS_sc4_layer5x5x5x5_swish_growthRate12_reshfl_SNR20to100.hdf5
# 2019-02-15_00:16:45 - Epoch: 2, val_loss: 0.000226, loss: 0.000234
# Epoch 3/20
# 7923/7923 [==============================] - 4854s 613ms/step - loss: 2.1906e-04 - val_loss: 2.1738e-04
#
# Epoch 00003: val_loss improved from 0.00023 to 0.00022, saving model to DeconvNet2D_FCS_sc4_layer5x5x5x5_swish_growthRate12_reshfl_SNR20to100.hdf5
# 2019-02-15_01:37:40 - Epoch: 3, val_loss: 0.000217, loss: 0.000219
# Epoch 4/20
# 3756/7923 [=============>................] - ETA: 40:32 - loss: 2.1538e-04

# %%
dnn.network_name
del dnn
k.clear_session()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-057501d0d46e> in <module>
#       1 dnn.network_name
#       2 del dnn
# ----> 3 k.clear_session()
#
# AttributeError: 'int' object has no attribute 'clear_session'

# %%
#
#SNR=100

# noiseless_img_hdu = 1
# targets_hdu = 4
# psf_hdu = 3
# deconv_mode = 'TIKHONOV'

# #Train with the image-000-0.fits as validation and all the other files as training set
# dnn.train_generator(gal_files[2:], gal_files[1], epochs=20, batch_size=32,
#                         nb_img_per_file=10000, validation_set_size=10000,
#                         noise_std=None, SNR=SNR, model_file='',
#                         noiseless_img_hdu=noiseless_img_hdu, targets_hdu=targets_hdu, psf_hdu=psf_hdu,
#                         image_dim=96, image_per_row=100,
#                         deconv_mode=deconv_mode)

#The train_generator is:
#1) running get_batch_from_fits for validation data: read files, deconv if necessary, return as [ngal,X2D,Y2D,1]
#2) setting a checkpoint for model, saving the model if lower validation loss
#3) using a generator function to obtain dynamic batches: dynamic_batches 
#   that I modified because it was assuming nb_img_per_file to be 10000 (hardcoded)
#4) running fit_generator with logging and checkpoint callbacks 

#I modified
# Out:
# Model will be saved at /home/fsureau/programs/DeepDeconv/UNet2D_FCS_sc3_layer4x4x4_relu_filt16_resNet.hdf5
# Memory usage for the model + one batch (GB): 0.881000
# /home/fsureau/programs/DeepDeconv/deepnet/DeepNet.py:133: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<generator..., epochs=20, validation_data=(array([[[..., verbose=1, callbacks=[<keras.ca..., steps_per_epoch=5947)`
#   callbacks=[model_checkpoint, LoggingCallback(filetxt=logfile, log=write_log)])
# Epoch 1/20
# 5947/5947 [==============================] - 2227s 374ms/step - loss: 8.3007e-04 - val_loss: 2.3895e-04
#
# Epoch 00001: val_loss improved from inf to 0.00024, saving model to UNet2D_FCS_sc3_layer4x4x4_relu_filt16_resNet.hdf5
# 2019-01-11_16:11:34 - Epoch: 1, val_loss: 0.000239, loss: 0.000831
# Epoch 2/20
# 5947/5947 [==============================] - 1488s 250ms/step - loss: 2.0572e-04 - val_loss: 1.8464e-04
#
# Epoch 00002: val_loss improved from 0.00024 to 0.00018, saving model to UNet2D_FCS_sc3_layer4x4x4_relu_filt16_resNet.hdf5
# 2019-01-11_16:36:23 - Epoch: 2, val_loss: 0.000185, loss: 0.000206
# Epoch 3/20
# 5947/5947 [==============================] - 1523s 256ms/step - loss: 1.8142e-04 - val_loss: 1.7455e-04
#
# Epoch 00003: val_loss improved from 0.00018 to 0.00017, saving model to UNet2D_FCS_sc3_layer4x4x4_relu_filt16_resNet.hdf5
# 2019-01-11_17:01:46 - Epoch: 3, val_loss: 0.000175, loss: 0.000181
# Epoch 4/20
# 5947/5947 [==============================] - 1466s 246ms/step - loss: 1.7367e-04 - val_loss: 1.7240e-04
#
# Epoch 00004: val_loss improved from 0.00017 to 0.00017, saving model to UNet2D_FCS_sc3_layer4x4x4_relu_filt16_resNet.hdf5
# 2019-01-11_17:26:13 - Epoch: 4, val_loss: 0.000172, loss: 0.000174
# Epoch 5/20
# 5947/5947 [==============================] - 1452s 244ms/step - loss: 1.7092e-04 - val_loss: 1.6881e-04
#
# Epoch 00005: val_loss improved from 0.00017 to 0.00017, saving model to UNet2D_FCS_sc3_layer4x4x4_relu_filt16_resNet.hdf5
# 2019-01-11_17:50:26 - Epoch: 5, val_loss: 0.000169, loss: 0.000171
# Epoch 6/20
# 5947/5947 [==============================] - 1402s 236ms/step - loss: 1.6938e-04 - val_loss: 1.7055e-04
#
# Epoch 00006: val_loss did not improve from 0.00017
# 2019-01-11_18:13:48 - Epoch: 6, val_loss: 0.000171, loss: 0.000169
# Epoch 7/20
# 5947/5947 [==============================] - 1373s 231ms/step - loss: 1.6862e-04 - val_loss: 1.7092e-04
#
# Epoch 00007: val_loss did not improve from 0.00017
# 2019-01-11_18:36:41 - Epoch: 7, val_loss: 0.000171, loss: 0.000169
# Epoch 8/20
# 5947/5947 [==============================] - 1375s 231ms/step - loss: 1.6802e-04 - val_loss: 1.7414e-04
#
# Epoch 00008: val_loss did not improve from 0.00017
# 2019-01-11_18:59:37 - Epoch: 8, val_loss: 0.000174, loss: 0.000168
# Epoch 9/20
# 5947/5947 [==============================] - 1355s 228ms/step - loss: 1.6754e-04 - val_loss: 1.6746e-04
#
# Epoch 00009: val_loss improved from 0.00017 to 0.00017, saving model to UNet2D_FCS_sc3_layer4x4x4_relu_filt16_resNet.hdf5
# 2019-01-11_19:22:12 - Epoch: 9, val_loss: 0.000167, loss: 0.000168
# Epoch 10/20
# 5947/5947 [==============================] - 1244s 209ms/step - loss: 1.6698e-04 - val_loss: 1.7681e-04
#
# Epoch 00010: val_loss did not improve from 0.00017
# 2019-01-11_19:42:55 - Epoch: 10, val_loss: 0.000177, loss: 0.000167
# Epoch 11/20
# 5947/5947 [==============================] - 1256s 211ms/step - loss: 1.6661e-04 - val_loss: 1.7059e-04
#
# Epoch 00011: val_loss did not improve from 0.00017
# 2019-01-11_20:03:51 - Epoch: 11, val_loss: 0.000171, loss: 0.000167
# Epoch 12/20
# 5947/5947 [==============================] - 1241s 209ms/step - loss: 1.6625e-04 - val_loss: 1.6631e-04
#
# Epoch 00012: val_loss improved from 0.00017 to 0.00017, saving model to UNet2D_FCS_sc3_layer4x4x4_relu_filt16_resNet.hdf5
# 2019-01-11_20:24:33 - Epoch: 12, val_loss: 0.000166, loss: 0.000166
# Epoch 13/20
# 5947/5947 [==============================] - 1236s 208ms/step - loss: 1.6602e-04 - val_loss: 1.6726e-04
#
# Epoch 00013: val_loss did not improve from 0.00017
# 2019-01-11_20:45:09 - Epoch: 13, val_loss: 0.000167, loss: 0.000166
# Epoch 14/20
# 5947/5947 [==============================] - 1227s 206ms/step - loss: 1.6581e-04 - val_loss: 1.6633e-04
#
# Epoch 00014: val_loss did not improve from 0.00017
# 2019-01-11_21:05:35 - Epoch: 14, val_loss: 0.000166, loss: 0.000166
# Epoch 15/20
# 5947/5947 [==============================] - 1241s 209ms/step - loss: 1.6565e-04 - val_loss: 1.6528e-04
#
# Epoch 00015: val_loss improved from 0.00017 to 0.00017, saving model to UNet2D_FCS_sc3_layer4x4x4_relu_filt16_resNet.hdf5
# 2019-01-11_21:26:17 - Epoch: 15, val_loss: 0.000165, loss: 0.000166
# Epoch 16/20
# 5947/5947 [==============================] - 1235s 208ms/step - loss: 1.6542e-04 - val_loss: 1.6577e-04
#
# Epoch 00016: val_loss did not improve from 0.00017
# 2019-01-11_21:46:52 - Epoch: 16, val_loss: 0.000166, loss: 0.000165
# Epoch 17/20
# 5947/5947 [==============================] - 1246s 210ms/step - loss: 1.6537e-04 - val_loss: 1.6562e-04
#
# Epoch 00017: val_loss did not improve from 0.00017
# 2019-01-11_22:07:38 - Epoch: 17, val_loss: 0.000166, loss: 0.000165
# Epoch 18/20
# 5947/5947 [==============================] - 1275s 214ms/step - loss: 1.6507e-04 - val_loss: 1.7128e-04
#
# Epoch 00018: val_loss did not improve from 0.00017
# 2019-01-11_22:28:53 - Epoch: 18, val_loss: 0.000171, loss: 0.000165
# Epoch 19/20
# 5947/5947 [==============================] - 1250s 210ms/step - loss: 1.6499e-04 - val_loss: 2.3569e-04
#
# Epoch 00019: val_loss did not improve from 0.00017
# 2019-01-11_22:49:43 - Epoch: 19, val_loss: 0.000236, loss: 0.000165
# Epoch 20/20
# 5947/5947 [==============================] - 1216s 205ms/step - loss: 1.6497e-04 - val_loss: 1.6573e-04
#
# Epoch 00020: val_loss did not improve from 0.00017
# 2019-01-11_23:10:00 - Epoch: 20, val_loss: 0.000166, loss: 0.000165
